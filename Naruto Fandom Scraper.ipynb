# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
res = requests.get('https://naruto.fandom.com/wiki/Category:Characters')
res2 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=Fugai%0AFugai')
res3 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=H%C5%8Dki+%28Watari%29%0AH%C5%8Dki+%28Watari%29')
res4 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=Kohari+Umino%0AKohari+Umino')
res5 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=Nang%C5%8D%0ANang%C5%8D')
res6 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=Shishio%0AShishio')
res7 = requests.get('https://naruto.fandom.com/wiki/Category:Characters?from=Uroko+Kurama%0AUroko+Kurama')

links = [res,res2,res3,res4,res5,res6,res7]
page = list()
for link in links:
    page.append(BeautifulSoup(link.text, 'html.parser'))
    print('link parsed!')
# Out:
# link parsed!
# link parsed!
# link parsed!
# link parsed!
# link parsed!
# link parsed!
# link parsed!

# %%
atags = list()
main = list()
siteLinks = list()
characterNames = list()
characterImages = list()
for html in page:
    atags=html.select('.category-page__member-link')
    imgtags = html.select('.category-page__member-thumbnail')
    for data in atags:
        siteLinks.append(data.get('href'))
        characterNames.append(data.getText())
        a='img[alt=\''#+data.getText()+'\']'
        print(a)
        img = html.select("img[alt='"+data.getText()+"']")
        #print(img)
        #characterImages.append(data.get('src'))#doesnt work as there are data-image links in it
#       #characterImages.append(data.get('src'))
        
        
        
#     for data in imgtags:
#         datasrc=data.get('data-src')
#         src=data.get('src')
#         characterImages.append(data.get('src'))#doesnt work as there are data-image links in it
#         characterImages.append(data.get('src'))#doesnt work as there are none field links in it        
#         if(datasrc != None):
#             characterImages.append(data.get('data-src'))
#         else:
#             characterImages.append(data.get('src'))
# characterImages = list(dict.fromkeys(characterImages))


for i,l in enumerate(siteLinks):
    #print(siteLinks[i], characterNames[i],characterImages[i])
    pass
    #main.append({'id':i,'link':siteLinks[i],'name':characterNames[i],'imageUrl':characterImages[i]})
# print(len(characterImages))
# print(main)
# pd.DataFrame(main)
# Out:
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# img[alt='
# Traceback (most recent call last):
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-89-dd0844f6f223>", line 14, in <module>
#     img = html.select("img[alt='"+data.getText()+"']")
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py", line 1784, in select
#     results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#
#   File "C:\ProgramData\Anaconda3\lib\site-packages\soupsieve\__init__.py", line 114, in select
#     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
# ...

# %%
for i,link in enumerate(characterImages):
    print(i,link)
# Out:
# 0 https://vignette.wikia.nocookie.net/naruto/images/3/37/1straikage.png
# 1 https://vignette.wikia.nocookie.net/naruto/images/3/37/1straikage.png
# 2 https://vignette.wikia.nocookie.net/naruto/images/4/4c/Fourth_Raikage_2.png
# 3 https://vignette.wikia.nocookie.net/naruto/images/4/4c/Fourth_Raikage_2.png
# 4 https://vignette.wikia.nocookie.net/naruto/images/3/3f/2nd_Raikage.png
# 5 https://vignette.wikia.nocookie.net/naruto/images/3/3f/2nd_Raikage.png
# 6 https://vignette.wikia.nocookie.net/naruto/images/f/f5/Raikage3.png
# 7 https://vignette.wikia.nocookie.net/naruto/images/f/f5/Raikage3.png
# 8 https://vignette.wikia.nocookie.net/naruto/images/7/72/Abiru_new.png
# 9 https://vignette.wikia.nocookie.net/naruto/images/7/72/Abiru_new.png
# 10 https://vignette.wikia.nocookie.net/naruto/images/7/71/Agara.png
# 11 https://vignette.wikia.nocookie.net/naruto/images/7/71/Agara.png
# 12 https://vignette.wikia.nocookie.net/naruto/images/5/5c/Agari.png
# ...

# %%
with open('characters.json','w') as f:
    f.write(json.dumps(main))
    print('success!!!!!')
    f.close()
# Out:
# success!!!!!
